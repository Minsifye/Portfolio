# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
plt.show()
# %matplotlib inline

# %%
ls
# Out:
# GlobalLandTemperaturesByCity.csv*      GlobalLandTemperaturesByState.csv*
# GlobalLandTemperaturesByCountry.csv*   GlobalTemperatures.csv*
# GlobalLandTemperaturesByMajorCity.csv* GlobalWarming.ipynb

# %%
city = pd.read_csv('GlobalLandTemperaturesByCity.csv')
state = pd.read_csv('GlobalLandTemperaturesByState.csv')
country = pd.read_csv('GlobalLandTemperaturesByCountry.csv')
temp = pd.read_csv('GlobalTemperatures.csv')
major_city = pd.read_csv('GlobalLandTemperaturesByMajorCity.csv')

# %%
city.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0  1743-11-01               6.068                          1.737  Århus
# 1  1743-12-01                 NaN                            NaN  Århus
# 2  1744-01-01                 NaN                            NaN  Århus
# 3  1744-02-01                 NaN                            NaN  Århus
# 4  1744-03-01                 NaN                            NaN  Århus
#
#    Country Latitude Longitude
# 0  Denmark   57.05N    10.33E
# 1  Denmark   57.05N    10.33E
# 2  Denmark   57.05N    10.33E
# 3  Denmark   57.05N    10.33E
# 4  Denmark   57.05N    10.33E

# %%
state.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty State Country
# 0  1855-05-01              25.544                          1.171  Acre  Brazil
# 1  1855-06-01              24.228                          1.103  Acre  Brazil
# 2  1855-07-01              24.371                          1.044  Acre  Brazil
# 3  1855-08-01              25.427                          1.073  Acre  Brazil
# 4  1855-09-01              25.675                          1.014  Acre  Brazil

# %%
country.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty Country
# 0  1743-11-01               4.384                          2.294   Åland
# 1  1743-12-01                 NaN                            NaN   Åland
# 2  1744-01-01                 NaN                            NaN   Åland
# 3  1744-02-01                 NaN                            NaN   Åland
# 4  1744-03-01                 NaN                            NaN   Åland

# %%
temp.head()
# Out:
#            dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0  1750-01-01                   3.034                              3.574
# 1  1750-02-01                   3.083                              3.702
# 2  1750-03-01                   5.626                              3.076
# 3  1750-04-01                   8.490                              2.451
# 4  1750-05-01                  11.573                              2.072
#
#    LandMaxTemperature  LandMaxTemperatureUncertainty  LandMinTemperature  \
# 0                 NaN                            NaN                 NaN
# 1                 NaN                            NaN                 NaN
# 2                 NaN                            NaN                 NaN
# 3                 NaN                            NaN                 NaN
# 4                 NaN                            NaN                 NaN
#
#    LandMinTemperatureUncertainty  LandAndOceanAverageTemperature  \
# ...

# %%
major_city.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty     City  \
# 0  1849-01-01              26.704                          1.435  Abidjan
# 1  1849-02-01              27.434                          1.362  Abidjan
# 2  1849-03-01              28.101                          1.612  Abidjan
# 3  1849-04-01              26.140                          1.387  Abidjan
# 4  1849-05-01              25.427                          1.200  Abidjan
#
#          Country Latitude Longitude
# 0  Côte D'Ivoire    5.63N     3.23W
# 1  Côte D'Ivoire    5.63N     3.23W
# 2  Côte D'Ivoire    5.63N     3.23W
# 3  Côte D'Ivoire    5.63N     3.23W
# 4  Côte D'Ivoire    5.63N     3.23W

# %%
country.head(10)
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty Country  Year
# 0  1743-11-01               4.384                          2.294   Åland  1743
# 1  1743-12-01                 NaN                            NaN   Åland  1743
# 2  1744-01-01                 NaN                            NaN   Åland  1744
# 3  1744-02-01                 NaN                            NaN   Åland  1744
# 4  1744-03-01                 NaN                            NaN   Åland  1744
# 5  1744-04-01               1.530                          4.680   Åland  1744
# 6  1744-05-01               6.702                          1.789   Åland  1744
# 7  1744-06-01              11.609                          1.577   Åland  1744
# 8  1744-07-01              15.342                          1.410   Åland  1744
# 9  1744-08-01                 NaN                            NaN   Åland  1744

# %%
country['Country'].unique()
# Out:
# array(['Åland', 'Afghanistan', 'Africa', 'Albania', 'Algeria',
#        'American Samoa', 'Andorra', 'Angola', 'Anguilla', 'Antarctica',
#        'Antigua And Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Asia',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Baker Island', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium',
#        'Belize', 'Benin', 'Bhutan', 'Bolivia',
#        'Bonaire, Saint Eustatius And Saba', 'Bosnia And Herzegovina',
#        'Botswana', 'Brazil', 'British Virgin Islands', 'Bulgaria',
#        'Burkina Faso', 'Burma', 'Burundi', "Côte D'Ivoire", 'Cambodia',
#        'Cameroon', 'Canada', 'Cape Verde', 'Cayman Islands',
#        'Central African Republic', 'Chad', 'Chile', 'China',
#        'Christmas Island', 'Colombia', 'Comoros',
#        'Congo (Democratic Republic Of The)', 'Congo', 'Costa Rica',
#        'Croatia', 'Cuba', 'Curaçao', 'Cyprus', 'Czech Republic',
#        'Denmark (Europe)', 'Denmark', 'Djibouti', 'Dominica',
# ...

# %%
country.shape[0]
# Out:
# 577462

# %%
country.columns
# Out:
# Index(['dt', 'AverageTemperature', 'AverageTemperatureUncertainty', 'Country',
#        'Year'],
#       dtype='object')

# %%
country['dt'].head(10)
# Out:
# 0    1743-11-01
# 1    1743-12-01
# 2    1744-01-01
# 3    1744-02-01
# 4    1744-03-01
# 5    1744-04-01
# 6    1744-05-01
# 7    1744-06-01
# 8    1744-07-01
# 9    1744-08-01
# Name: dt, dtype: object

# %% [markdown]
# Let's clean dates data and convert them into year

# %%
country['Year'] = df['year']

# %%
df = pd.DataFrame(country['dt'])

# %%
df.head()
# Out:
#            dt
# 0  1743-11-01
# 1  1743-12-01
# 2  1744-01-01
# 3  1744-02-01
# 4  1744-03-01

# %%
dt_list = []
for i in range(df.shape[0]):
    dt_list.append(int(df['dt'][i].split('-')[0]))

# %%
int(df['dt'][i].split('-')[0])
# Out:
# 2013

# %%
df.shape[0]
# Out:
# 577462

# %%
df['year'] =pd.DataFrame(dt_list)

# %%
df.head(2)
# Out:
#            dt  year
# 0  1743-11-01  1743
# 1  1743-12-01  1743

# %%
country.head()
# Out:
#    AverageTemperature  AverageTemperatureUncertainty Country  Year
# 0               4.384                          2.294   Åland  1743
# 5               1.530                          4.680   Åland  1744
# 6               6.702                          1.789   Åland  1744
# 7              11.609                          1.577   Åland  1744
# 8              15.342                          1.410   Åland  1744

# %%
country.dropna(thresh=5, inplace=True)

# %%
country.drop(columns=['dt'], inplace=True)

# %%
country.groupby(['Country', 'Year']).mean().head(1)
# Out:
#                   AverageTemperature  AverageTemperatureUncertainty
# Country     Year
# Afghanistan 1838           18.379571                          2.756

# %%
india = pd.DataFrame(country[country['Country']=='India'].groupby('Year').mean())

# %%
india.head()
# Out:
#    Year  AverageTemperature  AverageTemperatureUncertainty
# 0  1796           23.675250                       2.294417
# 1  1797           24.839900                       2.145600
# 2  1798           23.273300                       2.170500
# 3  1799           23.949417                       1.916417
# 4  1800           23.911917                       1.961167

# %%
US = pd.DataFrame(country[country['Country']=='United States'].groupby('Year').mean())

# %%
US.reset_index(inplace=True)

# %%
US.head()
# Out:
#    Year  AverageTemperature  AverageTemperatureUncertainty
# 0  1768            5.572750                       3.757000
# 1  1769           10.446500                       3.693375
# 2  1774            1.603000                       3.632667
# 3  1775            9.499167                       2.755083
# 4  1776            8.110000                       2.962091

# %%
sns.pairplot(country[country['Country']=='India'].groupby('Year').mean())

# %%
sns.lmplot(x="Year", y="AverageTemperature", data=india);

# %%
sns.lmplot(x='Year', y='AverageTemperature', data = US)

# %%
major_city.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty     City  \
# 0  1849-01-01              26.704                          1.435  Abidjan
# 1  1849-02-01              27.434                          1.362  Abidjan
# 2  1849-03-01              28.101                          1.612  Abidjan
# 3  1849-04-01              26.140                          1.387  Abidjan
# 4  1849-05-01              25.427                          1.200  Abidjan
#
#          Country Latitude Longitude
# 0  Côte D'Ivoire    5.63N     3.23W
# 1  Côte D'Ivoire    5.63N     3.23W
# 2  Côte D'Ivoire    5.63N     3.23W
# 3  Côte D'Ivoire    5.63N     3.23W
# 4  Côte D'Ivoire    5.63N     3.23W

# %%
major_city['City'].unique()
# Out:
# array(['Abidjan', 'Addis Abeba', 'Ahmadabad', 'Aleppo', 'Alexandria',
#        'Ankara', 'Baghdad', 'Bangalore', 'Bangkok', 'Belo Horizonte',
#        'Berlin', 'Bogotá', 'Bombay', 'Brasília', 'Cairo', 'Calcutta',
#        'Cali', 'Cape Town', 'Casablanca', 'Changchun', 'Chengdu',
#        'Chicago', 'Chongqing', 'Dakar', 'Dalian', 'Dar Es Salaam',
#        'Delhi', 'Dhaka', 'Durban', 'Faisalabad', 'Fortaleza', 'Gizeh',
#        'Guangzhou', 'Harare', 'Harbin', 'Ho Chi Minh City', 'Hyderabad',
#        'Ibadan', 'Istanbul', 'Izmir', 'Jaipur', 'Jakarta', 'Jiddah',
#        'Jinan', 'Kabul', 'Kano', 'Kanpur', 'Karachi', 'Kiev', 'Kinshasa',
#        'Lagos', 'Lahore', 'Lakhnau', 'Lima', 'London', 'Los Angeles',
#        'Luanda', 'Madras', 'Madrid', 'Manila', 'Mashhad', 'Melbourne',
#        'Mexico', 'Mogadishu', 'Montreal', 'Moscow', 'Nagoya', 'Nagpur',
#        'Nairobi', 'Nanjing', 'New Delhi', 'New York', 'Paris', 'Peking',
# ...

# %%
major_city[major_city['City']=='New Delhi'][['AverageTemperature','AverageTemperatureUncertainty', 'dt']]
# Out:
#         AverageTemperature  AverageTemperatureUncertainty          dt
# 167156              14.590                          2.374  1796-01-01
# 167157              17.109                          1.940  1796-02-01
# 167158              21.454                          2.608  1796-03-01
# 167159              28.715                          2.122  1796-04-01
# 167160              33.726                          1.997  1796-05-01
# 167161              34.264                          3.018  1796-06-01
# 167162              31.321                          2.403  1796-07-01
# 167163              30.501                          2.842  1796-08-01
# 167164              29.103                          3.166  1796-09-01
# 167165              26.091                          1.752  1796-10-01
# 167166              20.178                          2.705  1796-11-01
# 167167              13.311                          3.473  1796-12-01
# ...

# %%
major_city['dt']
# Out:
# 0         1849-01-01
# 1         1849-02-01
# 2         1849-03-01
# 3         1849-04-01
# 4         1849-05-01
# 5         1849-06-01
# 6         1849-07-01
# 7         1849-08-01
# 8         1849-09-01
# 9         1849-10-01
# 10        1849-11-01
# 11        1849-12-01
# 12        1850-01-01
# 13        1850-02-01
# 14        1850-03-01
# 15        1850-04-01
# 16        1850-05-01
# 17        1850-06-01
# 18        1850-07-01
# 19        1850-08-01
# 20        1850-09-01
# 21        1850-10-01
# 22        1850-11-01
# 23        1850-12-01
# 24        1851-01-01
# 25        1851-02-01
# 26        1851-03-01
# 27        1851-04-01
# 28        1851-05-01
# 29        1851-06-01
#              ...
# 239147    2011-04-01
# 239148    2011-05-01
# 239149    2011-06-01
# 239150    2011-07-01
# 239151    2011-08-01
# 239152    2011-09-01
# 239153    2011-10-01
# 239154    2011-11-01
# 239155    2011-12-01
# 239156    2012-01-01
# 239157    2012-02-01
# 239158    2012-03-01
# ...

# %%
pwd
# Out:
# '/Users/monikabagyal/Elephant/dataset/ClimateChange/climate-change-earth-surface-temperature-data'
